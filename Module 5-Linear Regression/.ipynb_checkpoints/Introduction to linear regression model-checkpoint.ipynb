# %% [markdown]
# LINEAR REGRESSION MODEL?
#
# Previously we dealt with simple mean regression model(based on mean prediction and mean prediction based on some inpuut feature

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse

# %%
data=pd.read_csv('Transformed_Housing_Data2.csv')

# %%
data
# Out:
#        Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21604    360000.0               3             2.50               1530.0
# 21605    400000.0               4             2.50               2310.0
# 21606    402101.0               2             0.75               1020.0
# 21607    400000.0               3             2.50               1600.0
# 21608    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# ...

# %%
sale_price=data['Sale_Price'].head(30)
flat_area=data['Flat Area (in Sqft)'].head(30)
sample_data=pd.DataFrame({'sale_price':sale_price,'flat_area':flat_area})
sample_data
# Out:
#     sale_price  flat_area
# 0     221900.0     1180.0
# 1     538000.0     2570.0
# 2     180000.0      770.0
# 3     604000.0     1960.0
# 4     510000.0     1680.0
# 5    1129575.0     5420.0
# 6     257500.0     1715.0
# 7     291850.0     1060.0
# 8     229500.0     1780.0
# 9     323000.0     1890.0
# 10    662500.0     3560.0
# 11    468000.0     1160.0
# 12    310000.0     1430.0
# 13    400000.0     1370.0
# 14    530000.0     1810.0
# 15    650000.0     2950.0
# 16    395000.0     1890.0
# 17    485000.0     1600.0
# 18    189000.0     1200.0
# 19    230000.0     1250.0
# 20    385000.0     1620.0
# 21   1129575.0     3050.0
# 22    285000.0     2270.0
# 23    252700.0     1070.0
# 24    329000.0     2450.0
# 25    233000.0     1710.0
# 26    937000.0     2450.0
# 27    667000.0     1400.0
# 28    438000.0     1520.0
# 29    719000.0     2570.0

# %%
plt.figure(dpi=100)
plt.scatter(sample_data.flat_area,sample_data.sale_price,color='red')
plt.xlabel('Flat_area')
plt.ylabel('sale_price')
plt.title('Sale price/ Flat area')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#from graph we observe that with increase in flat area, sale price also increase
#build a mean regression model to predict the sale _price
sample_data['mean_sale_price']=sample_data.sale_price.mean()
plt.figure(dpi=100)
plt.scatter(sample_data.flat_area,sample_data.sale_price,color='red',label='Sale Price')
plt.plot(sample_data.flat_area,sample_data.mean_sale_price,color='black',label='Mean Sale Price')
plt.xlabel('Flat_area')
plt.ylabel('sale_price')
plt.title('Sale price/ Flat area')
plt.legend()
plt.show()

# %% [markdown]
# Linear regression model- It models the relationship between the dependent and independent variable
#
# The parameters of linear regression model
#
# The best   linear regression model is that which has the least error
# y=mx+c
#
# x is independent and y is dependent,m is slopee and c the intercept , the point at which line cuts the y axis, slope m and c are known as the parameters of the line
#
# COST FUNCTION CURVE
#  How we can find the parameters m and c which represents the best fit line

# %%
c=0
m=0
line=[]

for i in range(len(sample_data)):
    line.append(sample_data.flat_area[i]*m+c)
    
plt.figure(dpi=100)
plt.scatter(sample_data.flat_area,sample_data.sale_price)
plt.plot(sample_data.flat_area,line)
plt.xlabel('Flat_area')
plt.title("Slope "+str(m)+' with MSE '+str(MSE))
plt.ylabel('sale_price')
MSE=mse(sample_data.sale_price,line)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
c=0
m=50
line=[]

for i in range(len(sample_data)):
    line.append(sample_data.flat_area[i]*m+c)
    
plt.figure(dpi=100)
plt.scatter(sample_data.flat_area,sample_data.sale_price)
plt.plot(sample_data.flat_area,line)
plt.xlabel('Flat_area')
plt.ylabel('sale_price')
MSE=mse(sample_data.sale_price,line)
plt.title("Slope "+str(m)+' with MSE '+str(MSE))
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
def slope_error(m,c,sample_data):
    sale=[]
    for i in range(len(sample_data.flat_area)):
        tmp=sample_data.flat_area[i]*m+c
        sale.append(tmp)
    MSE=mse(sample_data.sale_price,sale)
    return MSE

# %%
slope=[i/10 for i in range(0,5000)]
Cost=[]
for i in slope:
    cost=slope_error(m=i,c=0,sample_data=sample_data)
    Cost.append(cost)

# %%
cost_table=pd.DataFrame({
    'slope':slope,
    'Cost':Cost
})
cost_table
# Out:
#       slope          Cost
# 0       0.0  2.813721e+11
# 1       0.1  2.811558e+11
# 2       0.2  2.809395e+11
# 3       0.3  2.807234e+11
# 4       0.4  2.805073e+11
# ...     ...           ...
# 4995  499.5  3.526038e+11
# 4996  499.6  3.528488e+11
# 4997  499.7  3.530938e+11
# 4998  499.8  3.533389e+11
# 4999  499.9  3.535842e+11
#
# [5000 rows x 2 columns]

# %%
#plotting the cost values corresponding to every value of data
plt.plot(cost_table.slope,cost_table.Cost,label='Cost function curve')
plt.xlabel('Value of the slope')
plt.ylabel('Cost')
plt.legend()

# %% [markdown]
# Cost function curve is the error corresponding to different models(error corresponding to lines with different slopes)
# Convex =global minimum
# nin conves curves=local minima
#
# Explain how cost or loss function curve can
# be used to find the parameters of the linear
# regression model.
# Explain the need for gradient descent
# algorithm.

# %%
new_slope = cost_table['slope'][cost_table['Cost'] == cost_table['Cost'].min()].values
new_slope[0]
# Out:
# 234.3

# %%
def intercept_error(m,c,sample_data):
    sale=[]
    for i in range(len(sample_data.flat_area)):
        tmp=sample_data.flat_area[i]*m+c
        sale.append(tmp)
    MSE=mse(sample_data.sale_price,sale)
    return MSE

# %%
intercept=[i for i in range(5000,50000)]
Cost=[]
for i in intercept:
    cost=intercept_error(m=234,c=i,sample_data=sample_data)
    Cost.append(cost)

# %%
cost_table=pd.DataFrame({
    'Intercept':intercept,
    'Cost':Cost
})
cost_table
# Out:
#        Intercept          Cost
# 0           5000  2.779911e+10
# 1           5001  2.779909e+10
# 2           5002  2.779908e+10
# 3           5003  2.779907e+10
# 4           5004  2.779906e+10
# ...          ...           ...
# 44995      49995  2.929862e+10
# 44996      49996  2.929870e+10
# 44997      49997  2.929878e+10
# 44998      49998  2.929886e+10
# 44999      49999  2.929894e+10
#
# [45000 rows x 2 columns]

# %%
#plotting the cost values corresponding to every value of data
plt.plot(cost_table.Intercept,cost_table.Cost,label='Cost function curve')
plt.xlabel('Value of the slope')
plt.ylabel('Cost')
plt.legend()

# %%
new_intercept = cost_table['Intercept'][cost_table['Cost'] == cost_table['Cost'].min()].values
new_intercept[0]
# Out:
# 10834

# %%
slope=[i/10 for i in range(0,5000)]
Cost=[]
for i in slope:
    cost=slope_error(m=i,c=10834,sample_data=sample_data)
    Cost.append(cost)

# %%
cost_table=pd.DataFrame({
    'slope':slope,
    'Cost':Cost
})
cost_table
# Out:
#       slope          Cost
# 0       0.0  2.713921e+11
# 1       0.1  2.711800e+11
# 2       0.2  2.709680e+11
# 3       0.3  2.707560e+11
# 4       0.4  2.705442e+11
# ...     ...           ...
# 4995  499.5  3.636767e+11
# 4996  499.6  3.639259e+11
# 4997  499.7  3.641751e+11
# 4998  499.8  3.644245e+11
# 4999  499.9  3.646739e+11
#
# [5000 rows x 2 columns]

# %%
#plotting the cost values corresponding to every value of data
plt.plot(cost_table.slope,cost_table.Cost,label='Cost function curve')
plt.xlabel('Value of the slope')
plt.ylabel('Cost')
plt.legend()

# %%
new_slope = cost_table['slope'][cost_table['Cost'] == cost_table['Cost'].min()].values
new_slope[0]
# Out:
# 229.7

# %% [markdown]
# m=219,c=39428
# Finding the ideal slope and intercept of a line manually
# Possible
# Data with 1 variable
# for Data with several input variables:
# Y = c +m₁ X₁ + M2 X2 + M3 X3+ MnXn
# Where,
# X₁ represents the ith independent variablesm;
# mi represents the slope correspondingto that independent variable
#
# The major demerit of any simple mean regression model is that all the predictions are exactly equal.

# %% [markdown]
# GRADIENT DESCENT -helps to find the ideal value of m corrosponding to each and every independent variable automatically
